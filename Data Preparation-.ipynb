# %%
import pandas as pd
import numpy as np

# %%
covid_death=pd.read_csv(r'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/covid_Death.csv')
covid_death.head()
# Out:
#   iso_code continent     location        date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  24-02-2020  39835428.0          5.0
# 1      AFG      Asia  Afghanistan  25-02-2020  39835428.0          5.0
# 2      AFG      Asia  Afghanistan  26-02-2020  39835428.0          5.0
# 3      AFG      Asia  Afghanistan  27-02-2020  39835428.0          5.0
# 4      AFG      Asia  Afghanistan  28-02-2020  39835428.0          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
covid_vaccination=pd.read_csv(r'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/covid_Vaccination.csv')
covid_vaccination.head()
# Out:
#   iso_code continent     location        date  new_tests  total_tests  \
# 0      AFG      Asia  Afghanistan  24-02-2020        NaN          NaN
# 1      AFG      Asia  Afghanistan  25-02-2020        NaN          NaN
# 2      AFG      Asia  Afghanistan  26-02-2020        NaN          NaN
# 3      AFG      Asia  Afghanistan  27-02-2020        NaN          NaN
# 4      AFG      Asia  Afghanistan  28-02-2020        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  ...  female_smokers  male_smokers  \
# ...

# %%
covid_death.describe
# Out:
# <bound method NDFrame.describe of        iso_code continent     location        date  population  total_cases  \
# 0           AFG      Asia  Afghanistan  24-02-2020  39835428.0          5.0
# 1           AFG      Asia  Afghanistan  25-02-2020  39835428.0          5.0
# 2           AFG      Asia  Afghanistan  26-02-2020  39835428.0          5.0
# 3           AFG      Asia  Afghanistan  27-02-2020  39835428.0          5.0
# 4           AFG      Asia  Afghanistan  28-02-2020  39835428.0          5.0
# ...         ...       ...          ...         ...         ...          ...
# 132639      ZWE    Africa     Zimbabwe  07-11-2021  15092171.0     133187.0
# 132640      ZWE    Africa     Zimbabwe  08-11-2021  15092171.0     133205.0
# 132641      ZWE    Africa     Zimbabwe  09-11-2021  15092171.0     133242.0
# 132642      ZWE    Africa     Zimbabwe  10-11-2021  15092171.0     133302.0
# 132643      ZWE    Africa     Zimbabwe  11-11-2021  15092171.0     133329.0
#
# ...

# %%
covid_death.fillna("NULL",inplace=True)
covid_death
# Out:
#        iso_code continent     location        date  population total_cases  \
# 0           AFG      Asia  Afghanistan  24-02-2020  39835428.0         5.0
# 1           AFG      Asia  Afghanistan  25-02-2020  39835428.0         5.0
# 2           AFG      Asia  Afghanistan  26-02-2020  39835428.0         5.0
# 3           AFG      Asia  Afghanistan  27-02-2020  39835428.0         5.0
# 4           AFG      Asia  Afghanistan  28-02-2020  39835428.0         5.0
# ...         ...       ...          ...         ...         ...         ...
# 132639      ZWE    Africa     Zimbabwe  07-11-2021  15092171.0    133187.0
# 132640      ZWE    Africa     Zimbabwe  08-11-2021  15092171.0    133205.0
# 132641      ZWE    Africa     Zimbabwe  09-11-2021  15092171.0    133242.0
# 132642      ZWE    Africa     Zimbabwe  10-11-2021  15092171.0    133302.0
# 132643      ZWE    Africa     Zimbabwe  11-11-2021  15092171.0    133329.0
#
#        new_cases new_cases_smoothed total_deaths new_deaths  ...  \
# ...

# %%
covid_death.to_excel('covid_death_updated.xlsx')

# %%
pwd()
# Out:
# 'C:\\Users\\Jay Patel'

# %%
import os
os.chdir('C:/ProgramData/MySQL/MySQL Server 8.0/Uploads')

# %%
covid_death.to_excel('covid_death_updated.xlsx')

# %%
covid_death.to

# %%
pwd()
# Out:
# 'C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads'

# %%
covid_vaccination.fillna("NULL",inplace=True)
covid_vaccination
# Out:
#        iso_code continent     location        date new_tests total_tests  \
# 0           AFG      Asia  Afghanistan  24-02-2020      NULL        NULL
# 1           AFG      Asia  Afghanistan  25-02-2020      NULL        NULL
# 2           AFG      Asia  Afghanistan  26-02-2020      NULL        NULL
# 3           AFG      Asia  Afghanistan  27-02-2020      NULL        NULL
# 4           AFG      Asia  Afghanistan  28-02-2020      NULL        NULL
# ...         ...       ...          ...         ...       ...         ...
# 132639      ZWE    Africa     Zimbabwe  07-11-2021    1159.0   1393065.0
# 132640      ZWE    Africa     Zimbabwe  08-11-2021      NULL        NULL
# 132641      ZWE    Africa     Zimbabwe  09-11-2021      NULL        NULL
# 132642      ZWE    Africa     Zimbabwe  10-11-2021      NULL        NULL
# 132643      ZWE    Africa     Zimbabwe  11-11-2021      NULL        NULL
#
#        total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# ...

# %%
covid_vaccination.to_excel('covid_vaccination_updated.xlsx')

# %%
covid_vaccination.to_csv('covid_vaccination_updated.csv')

# %%
covid_death.to_csv('covid_death_updated.csv')
